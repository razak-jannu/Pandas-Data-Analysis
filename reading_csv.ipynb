# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\Local.Admin\\Desktop\\Python programs\\Pandas\\student_performance_dataset.csv",nrows=10)
csv_1
# Out:
#    student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0           1    Male               4.0                98.0          6.5
# 1           2  Female               6.3               100.0          5.7
# 2           3    Male               4.9                85.3          7.9
# 3           4    Male               2.6                77.5          8.0
# 4           5    Male               2.2                89.6          4.6
# 5           6  Female               4.2                78.2          5.7
# 6           7    Male               1.5               100.0          5.0
# 7           8    Male               6.2                86.4          6.0
# 8           9    Male               5.3                81.3          6.7
# 9          10  Female               2.8                86.8          5.1
#
#   parental_education internet_access extracurricular_activities part_time_job  \
# 0          Bachelors             Yes                        Yes            No
# ...

# %%
csv_1=pd.read_csv("C:\\Users\\Local.Admin\\Desktop\\Python programs\\Pandas\\student_performance_dataset.csv",usecols=[0,3])
csv_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 csv_1=pd.read_csv("C:\\Users\\Local.Admin\\Desktop\\Python programs\\Pandas\\student_performance_dataset.csv",usecols=[0,3])
#       2 csv_1
#
# NameError: name 'pd' is not defined

# %%
csv_1=pd.read_csv("C:\\Users\\Local.Admin\\Desktop\\Python programs\\Pandas\\student_performance_dataset.csv",skiprows=[1,2,5])
csv_1
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             3    Male               4.9                85.3          7.9
# 1             4    Male               2.6                77.5          8.0
# 2             6  Female               4.2                78.2          5.7
# 3             7    Male               1.5               100.0          5.0
# 4             8    Male               6.2                86.4          6.0
# ..          ...     ...               ...                 ...          ...
# 992         996    Male               2.8                75.4          8.2
# 993         997    Male               6.7                88.4          7.1
# 994         998  Female               2.6                84.5          8.0
# 995         999  Female               4.6                85.3          8.1
# 996        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
csv_1=pd.read_csv("C:\\Users\\Local.Admin\\Desktop\\Python programs\\Pandas\\student_performance_dataset.csv",index_col="student_id")
csv_1
# Out:
#             gender  study_time_hours  attendance_percent  sleep_hours  \
# student_id
# 1             Male               4.0                98.0          6.5
# 2           Female               6.3               100.0          5.7
# 3             Male               4.9                85.3          7.9
# 4             Male               2.6                77.5          8.0
# 5             Male               2.2                89.6          4.6
# ...            ...               ...                 ...          ...
# 996           Male               2.8                75.4          8.2
# 997           Male               6.7                88.4          7.1
# 998         Female               2.6                84.5          8.0
# 999         Female               4.6                85.3          8.1
# 1000          Male               3.9                77.4          6.1
#
#            parental_education internet_access extracurricular_activities  \
# student_id
# ...

# %%
csv_1=pd.read_csv("C:\\Users\\Local.Admin\\Desktop\\Python programs\\Pandas\\student_performance_dataset.csv",header=99)
csv_1
# Out:
#        99  Female  2.4  87.2  6.1  High School  Yes Yes.1 Yes.2  62.9  65.2  D
# 0     100    Male  1.4  94.3  7.8  High School   No    No    No  75.3  79.2  C
# 1     101    Male  2.5  70.8  6.3  High School  Yes   Yes    No  51.2  74.5  C
# 2     102  Female  1.9  67.4  6.7    Bachelors  Yes   Yes   Yes  75.5  66.3  D
# 3     103  Female  6.0  69.7  6.8    Bachelors   No    No    No  65.3  89.5  B
# 4     104  Female  4.8  97.6  4.5  High School  Yes    No    No  60.9  92.7  A
# ..    ...     ...  ...   ...  ...          ...  ...   ...   ...   ...   ... ..
# 896   996    Male  2.8  75.4  8.2      Masters  Yes   Yes    No  60.5  70.7  C
# 897   997    Male  6.7  88.4  7.1          NaN   No   Yes    No  82.2  99.5  A
# 898   998  Female  2.6  84.5  8.0  High School  Yes   Yes   Yes  65.2  79.2  C
# 899   999  Female  4.6  85.3  8.1  High School   No    No   Yes  52.2  82.2  B
# 900  1000    Male  3.9  77.4  6.1      Masters  Yes    No    No  45.4  70.4  C
#
# [901 rows x 12 columns]

# %%
csv_1.dtypes
# Out:
# student_id                      int64
# gender                            str
# study_time_hours              float64
# attendance_percent                str
# sleep_hours                   float64
# parental_education                str
# internet_access                   str
# extracurricular_activities        str
# part_time_job                     str
# previous_grade                float64
# final_exam_score              float64
# final_grade                       str
# dtype: object

# %%
csv_1=pd.read_csv("C:\\Users\\Local.Admin\\Desktop\\Python programs\\Pandas\\student_performance_dataset.csv",dtype={"attendance_percent":"float"})
csv_1
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
csv_1.dtypes
# Out:
# student_id                      int64
# gender                            str
# study_time_hours              float64
# attendance_percent            float64
# sleep_hours                   float64
# parental_education                str
# internet_access                   str
# extracurricular_activities        str
# part_time_job                     str
# previous_grade                float64
# final_exam_score              float64
# final_grade                       str
# dtype: object
